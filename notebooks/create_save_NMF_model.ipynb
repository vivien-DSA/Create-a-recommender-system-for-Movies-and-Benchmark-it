# %% [markdown]
# http://surpriselib.com

# %% [markdown]
# <h1 style="color:blue; font-weight:bold">Assignment todo list</h1>
#
# In this assignment you need to implement the get_user_recommendation function by following these steps :
# 1. Train a NMF model
#     1. Train a NMF model on the movielens dataset.
#     2. Save the model loacaly in the models folder.

# %%
# import useful libraries
import sys
sys.path.append("..")

# CREATE THE DATA_DIR PATH
from pathlib import Path
DATA_DIR = Path('../data/movielens/ml-latest-small')
MODELS_DIR = Path('../models/')

# %% [markdown]
# # Load data movielens dataset

# %%
# !pip install surprise
# Out:
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp38-cp38-win_amd64.whl size=707570 sha256=1878492ac7f0b683122d849d2b3ff302cfebdae9f3cdfd206c53789eae16cd59
#   Stored in directory: c:\users\vivie\appdata\local\pip\cache\wheels\20\91\57\2965d4cff1b8ac7ed1b6fa25741882af3974b54a31759e10b6
# Successfully built scikit-surprise
# ...

# %%
from recsys_dsa_20.pipeline import get_data

# %%
data = get_data(from_surprise=True)
data
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n]

# %% [markdown]
# ## Train the NMF model :

# %%
from recsys_dsa_20.pipeline import train_and_evalute_model_pipeline

# %%
# Train and evaluate NMF
from surprise import NMF
my_model, metrics_dict = train_and_evalute_model_pipeline(NMF)
metrics_dict
# Out:
# {'RMSE': 0.9606905132535603,
#  'MAE': 0.9606905132535603,
#  'test_time': 0.14269757270812988,
#  'fit_time': 4.255232572555542}

# %% [markdown]
# ## Save the model and metrics using pickle

# %%
# Save the model using pickle
import pickle
model_filename = 'Surprise_NMF_model.sav'

pickle.dump(my_model, open(MODELS_DIR/model_filename, 'wb'))
